# %%
# Import the NumPy library
import numpy as np

# %%
#  Function to normalize data in the range [0,1] using min-max feature scaling
def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

# Input data representing height and weight of patients
X = np.array([[161,  55],
              [183,  95],
              [171,  60],
              [194, 102],
              [162,  58],
              [185,  90],
             ])

# Normalize the input data
scaled_x = NormalizeData(X)

# Print the scaled input data
print(scaled_x)
# Out:
# [[0.76258993 0.        ]
#  [0.92086331 0.28776978]
#  [0.83453237 0.03597122]
#  [1.         0.3381295 ]
#  [0.76978417 0.02158273]
#  [0.9352518  0.25179856]]

# %%
# Sigmoid activation function : f(x) = 1 / (1 + e^(-x))
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
# Derivative of the sigmoid function : f'(x) = f(x) * (1 - f(x))
def deriv_sigmoid(x):
    fx = sigmoid(x)
    return fx * (1 - fx)

# %%
# Mean squared error loss function
def mse_loss(y_true, y_pred):
    return ((y_true - y_pred) ** 2).mean()

# %%
# Neural network class
class OurNeuralNetwork:
    def __init__(self):
        # Initialize random weights and biases
        self.w1 = np.random.normal()
        self.w2 = np.random.normal()
        self.w3 = np.random.normal()
        self.w4 = np.random.normal()
        self.w5 = np.random.normal()
        self.w6 = np.random.normal()
        
        self.b1 = 1
        self.b2 = 1
        self.b3 = 1
        
    def feedforward(self, x):
        # Forward pass through the network
        h1 = sigmoid(self.w1 * x[0] + self.w2 * x[1] + self.b1)
        h2 = sigmoid(self.w3 * x[0] + self.w4 * x[1] + self.b2)
        o1 = sigmoid(self.w5 * h1 + self.w6 * h2 + self.b3)
        return o1
    
    def train(self, data, all_y_trues):
        learn_rate = 0.1
        epochs = 1000
        
        for epoch in range(epochs):
            for x,y_true in zip(data, all_y_trues):
                # Forward pass
                sum_h1 = self.w1 * x[0] + self.w2 * x[1] + self.b1
                h1 = sigmoid(sum_h1)
                
                sum_h2 = self.w3 * x[0] + self.w4 * x[1] + self.b2
                h2 = sigmoid(sum_h2)
                
                sum_o1 = self.w5 * h1 + self.w6 * h2 + self.b3
                o1 = sigmoid(sum_o1)
                y_pred = o1
                
                # Backpropagation
                d_L_d_ypred = -2 * (y_true - y_pred)
                
                d_ypred_d_w5 = h1 * deriv_sigmoid(sum_o1)
                d_ypred_d_w6 = h2 * deriv_sigmoid(sum_o1)
                d_ypred_d_b3 = deriv_sigmoid(sum_o1)
                
                d_ypred_d_h1 = self.w5 * deriv_sigmoid(sum_o1)
                d_ypred_d_h2 = self.w6 * deriv_sigmoid(sum_o1)   
                
                d_h1_d_w1 = x[0] * deriv_sigmoid(sum_h1)
                d_h1_d_w2 = x[1] * deriv_sigmoid(sum_h1)
                d_h1_d_b1 = deriv_sigmoid(sum_h1)
                
                d_h2_d_w3 = x[0] * deriv_sigmoid(sum_h2)
                d_h2_d_w4 = x[1] * deriv_sigmoid(sum_h2)
                d_h2_d_b2 = deriv_sigmoid(sum_h2)
                
                # Update the weights and biases
                self.w1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w1
                self.w2 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_w2
                self.b1 -= learn_rate * d_L_d_ypred * d_ypred_d_h1 * d_h1_d_b1
                
                self.w3 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w3
                self.w4 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_w4
                self.b2 -= learn_rate * d_L_d_ypred * d_ypred_d_h2 * d_h2_d_b2
                
                self.w5 -= learn_rate * d_L_d_ypred * d_ypred_d_w5
                self.w6 -= learn_rate * d_L_d_ypred * d_ypred_d_w6
                self.b3 -= learn_rate * d_L_d_ypred * d_ypred_d_b3
                
                # Compute and print the loss every 10 epochs
                if epoch % 10 == 0:
                    y_preds = np.apply_along_axis(self.feedforward, 1, data)
                    loss = mse_loss(all_y_trues, y_preds)
                    print("Epoch %d loss: %.3f" % (epoch, loss))

# %%
# Define the input data and corresponding target values
data = np.array([[0.76258993, 0.00000000],
                 [0.92086331, 0.28776978],
                 [0.83453237, 0.03597122],
                 [1.00000000, 0.3381295 ],
                 [0.93525180, 0.25179856],
                ])

all_y_trues = np.array([0,
                        1,
                        0,
                        1,
                        1,
                       ])

# %%
# Create an instance of the OurNeuralNetwork class
network = OurNeuralNetwork()

# Train the neural network using the given input data and target values
network.train(data, all_y_trues)
# Out:
# Epoch 0 loss: 0.245
# Epoch 0 loss: 0.242
# Epoch 0 loss: 0.245
# Epoch 0 loss: 0.242
# Epoch 0 loss: 0.239
# Epoch 10 loss: 0.228
# Epoch 10 loss: 0.227
# Epoch 10 loss: 0.228
# Epoch 10 loss: 0.228
# Epoch 10 loss: 0.227
# Epoch 20 loss: 0.225
# Epoch 20 loss: 0.225
# Epoch 20 loss: 0.225
# Epoch 20 loss: 0.225
# Epoch 20 loss: 0.225
# Epoch 30 loss: 0.224
# Epoch 30 loss: 0.224
# Epoch 30 loss: 0.224
# Epoch 30 loss: 0.223
# Epoch 30 loss: 0.223
# Epoch 40 loss: 0.222
# Epoch 40 loss: 0.222
# Epoch 40 loss: 0.222
# Epoch 40 loss: 0.222
# Epoch 40 loss: 0.222
# Epoch 50 loss: 0.220
# Epoch 50 loss: 0.220
# Epoch 50 loss: 0.220
# Epoch 50 loss: 0.220
# Epoch 50 loss: 0.220
# Epoch 60 loss: 0.218
# Epoch 60 loss: 0.218
# Epoch 60 loss: 0.218
# Epoch 60 loss: 0.218
# Epoch 60 loss: 0.218
# Epoch 70 loss: 0.216
# Epoch 70 loss: 0.216
# Epoch 70 loss: 0.216
# Epoch 70 loss: 0.216
# Epoch 70 loss: 0.216
# Epoch 80 loss: 0.213
# Epoch 80 loss: 0.213
# Epoch 80 loss: 0.213
# Epoch 80 loss: 0.213
# Epoch 80 loss: 0.213
# Epoch 90 loss: 0.211
# Epoch 90 loss: 0.211
# Epoch 90 loss: 0.211
# Epoch 90 loss: 0.211
# Epoch 90 loss: 0.211
# Epoch 100 loss: 0.208
# Epoch 100 loss: 0.208
# Epoch 100 loss: 0.208
# Epoch 100 loss: 0.208
# Epoch 100 loss: 0.208
# Epoch 110 loss: 0.206
# Epoch 110 loss: 0.206
# Epoch 110 loss: 0.205
# Epoch 110 loss: 0.205
# Epoch 110 loss: 0.205
# Epoch 120 loss: 0.203
# Epoch 120 loss: 0.203
# Epoch 120 loss: 0.203
# Epoch 120 loss: 0.202
# Epoch 120 loss: 0.203
# Epoch 130 loss: 0.200
# Epoch 130 loss: 0.200
# Epoch 130 loss: 0.200
# Epoch 130 loss: 0.199
# Epoch 130 loss: 0.200
# Epoch 140 loss: 0.197
# Epoch 140 loss: 0.197
# Epoch 140 loss: 0.196
# Epoch 140 loss: 0.196
# Epoch 140 loss: 0.196
# Epoch 150 loss: 0.193
# Epoch 150 loss: 0.193
# Epoch 150 loss: 0.193
# Epoch 150 loss: 0.193
# Epoch 150 loss: 0.193
# Epoch 160 loss: 0.190
# Epoch 160 loss: 0.190
# Epoch 160 loss: 0.190
# Epoch 160 loss: 0.190
# Epoch 160 loss: 0.190
# Epoch 170 loss: 0.187
# Epoch 170 loss: 0.187
# Epoch 170 loss: 0.187
# Epoch 170 loss: 0.186
# Epoch 170 loss: 0.187
# Epoch 180 loss: 0.183
# Epoch 180 loss: 0.183
# Epoch 180 loss: 0.183
# Epoch 180 loss: 0.183
# Epoch 180 loss: 0.183
# Epoch 190 loss: 0.180
# Epoch 190 loss: 0.180
# Epoch 190 loss: 0.179
# Epoch 190 loss: 0.179
# Epoch 190 loss: 0.179
# Epoch 200 loss: 0.176
# Epoch 200 loss: 0.176
# Epoch 200 loss: 0.176
# Epoch 200 loss: 0.176
# Epoch 200 loss: 0.176
# Epoch 210 loss: 0.172
# Epoch 210 loss: 0.172
# Epoch 210 loss: 0.172
# Epoch 210 loss: 0.172
# Epoch 210 loss: 0.172
# Epoch 220 loss: 0.168
# Epoch 220 loss: 0.168
# Epoch 220 loss: 0.168
# Epoch 220 loss: 0.168
# Epoch 220 loss: 0.168
# Epoch 230 loss: 0.164
# Epoch 230 loss: 0.164
# Epoch 230 loss: 0.164
# Epoch 230 loss: 0.164
# Epoch 230 loss: 0.164
# Epoch 240 loss: 0.161
# Epoch 240 loss: 0.161
# Epoch 240 loss: 0.160
# Epoch 240 loss: 0.160
# Epoch 240 loss: 0.160
# Epoch 250 loss: 0.157
# Epoch 250 loss: 0.157
# Epoch 250 loss: 0.156
# Epoch 250 loss: 0.156
# Epoch 250 loss: 0.156
# Epoch 260 loss: 0.153
# Epoch 260 loss: 0.153
# Epoch 260 loss: 0.152
# Epoch 260 loss: 0.152
# Epoch 260 loss: 0.152
# Epoch 270 loss: 0.148
# Epoch 270 loss: 0.148
# Epoch 270 loss: 0.148
# Epoch 270 loss: 0.148
# Epoch 270 loss: 0.148
# Epoch 280 loss: 0.144
# Epoch 280 loss: 0.144
# Epoch 280 loss: 0.144
# Epoch 280 loss: 0.144
# Epoch 280 loss: 0.144
# Epoch 290 loss: 0.140
# Epoch 290 loss: 0.140
# Epoch 290 loss: 0.140
# Epoch 290 loss: 0.140
# Epoch 290 loss: 0.140
# Epoch 300 loss: 0.136
# Epoch 300 loss: 0.136
# Epoch 300 loss: 0.136
# Epoch 300 loss: 0.136
# Epoch 300 loss: 0.136
# Epoch 310 loss: 0.132
# Epoch 310 loss: 0.132
# Epoch 310 loss: 0.132
# Epoch 310 loss: 0.132
# Epoch 310 loss: 0.132
# Epoch 320 loss: 0.128
# Epoch 320 loss: 0.128
# Epoch 320 loss: 0.128
# Epoch 320 loss: 0.128
# Epoch 320 loss: 0.128
# Epoch 330 loss: 0.124
# Epoch 330 loss: 0.124
# Epoch 330 loss: 0.124
# Epoch 330 loss: 0.124
# Epoch 330 loss: 0.124
# Epoch 340 loss: 0.120
# Epoch 340 loss: 0.120
# Epoch 340 loss: 0.120
# Epoch 340 loss: 0.120
# Epoch 340 loss: 0.120
# Epoch 350 loss: 0.116
# Epoch 350 loss: 0.116
# Epoch 350 loss: 0.116
# Epoch 350 loss: 0.116
# Epoch 350 loss: 0.116
# Epoch 360 loss: 0.112
# Epoch 360 loss: 0.112
# Epoch 360 loss: 0.112
# Epoch 360 loss: 0.112
# Epoch 360 loss: 0.112
# Epoch 370 loss: 0.108
# Epoch 370 loss: 0.108
# Epoch 370 loss: 0.108
# Epoch 370 loss: 0.108
# Epoch 370 loss: 0.108
# Epoch 380 loss: 0.104
# Epoch 380 loss: 0.104
# Epoch 380 loss: 0.104
# Epoch 380 loss: 0.104
# Epoch 380 loss: 0.104
# Epoch 390 loss: 0.101
# Epoch 390 loss: 0.101
# Epoch 390 loss: 0.101
# Epoch 390 loss: 0.100
# Epoch 390 loss: 0.100
# Epoch 400 loss: 0.097
# Epoch 400 loss: 0.097
# Epoch 400 loss: 0.097
# Epoch 400 loss: 0.097
# Epoch 400 loss: 0.097
# Epoch 410 loss: 0.094
# Epoch 410 loss: 0.093
# Epoch 410 loss: 0.093
# Epoch 410 loss: 0.093
# Epoch 410 loss: 0.093
# Epoch 420 loss: 0.090
# Epoch 420 loss: 0.090
# Epoch 420 loss: 0.090
# Epoch 420 loss: 0.090
# Epoch 420 loss: 0.090
# Epoch 430 loss: 0.087
# Epoch 430 loss: 0.087
# Epoch 430 loss: 0.087
# Epoch 430 loss: 0.087
# Epoch 430 loss: 0.087
# Epoch 440 loss: 0.084
# Epoch 440 loss: 0.084
# Epoch 440 loss: 0.084
# Epoch 440 loss: 0.083
# Epoch 440 loss: 0.083
# Epoch 450 loss: 0.081
# Epoch 450 loss: 0.081
# Epoch 450 loss: 0.081
# Epoch 450 loss: 0.080
# Epoch 450 loss: 0.080
# Epoch 460 loss: 0.078
# Epoch 460 loss: 0.078
# Epoch 460 loss: 0.078
# Epoch 460 loss: 0.077
# Epoch 460 loss: 0.077
# Epoch 470 loss: 0.075
# Epoch 470 loss: 0.075
# Epoch 470 loss: 0.075
# Epoch 470 loss: 0.075
# Epoch 470 loss: 0.075
# Epoch 480 loss: 0.072
# Epoch 480 loss: 0.072
# Epoch 480 loss: 0.072
# Epoch 480 loss: 0.072
# Epoch 480 loss: 0.072
# Epoch 490 loss: 0.069
# Epoch 490 loss: 0.069
# Epoch 490 loss: 0.069
# Epoch 490 loss: 0.069
# Epoch 490 loss: 0.069
# Epoch 500 loss: 0.067
# Epoch 500 loss: 0.067
# Epoch 500 loss: 0.067
# Epoch 500 loss: 0.067
# Epoch 500 loss: 0.067
# Epoch 510 loss: 0.064
# Epoch 510 loss: 0.064
# Epoch 510 loss: 0.064
# Epoch 510 loss: 0.064
# Epoch 510 loss: 0.064
# Epoch 520 loss: 0.062
# Epoch 520 loss: 0.062
# Epoch 520 loss: 0.062
# Epoch 520 loss: 0.062
# Epoch 520 loss: 0.062
# Epoch 530 loss: 0.060
# Epoch 530 loss: 0.060
# Epoch 530 loss: 0.060
# Epoch 530 loss: 0.060
# Epoch 530 loss: 0.060
# Epoch 540 loss: 0.058
# Epoch 540 loss: 0.058
# Epoch 540 loss: 0.058
# Epoch 540 loss: 0.058
# Epoch 540 loss: 0.058
# Epoch 550 loss: 0.056
# Epoch 550 loss: 0.056
# Epoch 550 loss: 0.056
# Epoch 550 loss: 0.056
# Epoch 550 loss: 0.056
# Epoch 560 loss: 0.054
# Epoch 560 loss: 0.054
# Epoch 560 loss: 0.054
# Epoch 560 loss: 0.054
# Epoch 560 loss: 0.054
# Epoch 570 loss: 0.052
# Epoch 570 loss: 0.052
# Epoch 570 loss: 0.052
# Epoch 570 loss: 0.052
# Epoch 570 loss: 0.052
# Epoch 580 loss: 0.050
# Epoch 580 loss: 0.050
# Epoch 580 loss: 0.050
# Epoch 580 loss: 0.050
# Epoch 580 loss: 0.050
# Epoch 590 loss: 0.048
# Epoch 590 loss: 0.048
# Epoch 590 loss: 0.048
# Epoch 590 loss: 0.048
# Epoch 590 loss: 0.048
# Epoch 600 loss: 0.047
# Epoch 600 loss: 0.047
# Epoch 600 loss: 0.047
# Epoch 600 loss: 0.047
# Epoch 600 loss: 0.047
# Epoch 610 loss: 0.045
# Epoch 610 loss: 0.045
# Epoch 610 loss: 0.045
# Epoch 610 loss: 0.045
# Epoch 610 loss: 0.045
# Epoch 620 loss: 0.044
# Epoch 620 loss: 0.044
# Epoch 620 loss: 0.044
# Epoch 620 loss: 0.044
# Epoch 620 loss: 0.044
# Epoch 630 loss: 0.042
# Epoch 630 loss: 0.042
# Epoch 630 loss: 0.042
# Epoch 630 loss: 0.042
# Epoch 630 loss: 0.042
# Epoch 640 loss: 0.041
# Epoch 640 loss: 0.041
# Epoch 640 loss: 0.041
# Epoch 640 loss: 0.041
# Epoch 640 loss: 0.041
# Epoch 650 loss: 0.040
# Epoch 650 loss: 0.040
# Epoch 650 loss: 0.040
# Epoch 650 loss: 0.040
# Epoch 650 loss: 0.040
# Epoch 660 loss: 0.038
# Epoch 660 loss: 0.038
# Epoch 660 loss: 0.038
# Epoch 660 loss: 0.038
# Epoch 660 loss: 0.038
# Epoch 670 loss: 0.037
# Epoch 670 loss: 0.037
# Epoch 670 loss: 0.037
# Epoch 670 loss: 0.037
# Epoch 670 loss: 0.037
# Epoch 680 loss: 0.036
# Epoch 680 loss: 0.036
# Epoch 680 loss: 0.036
# Epoch 680 loss: 0.036
# Epoch 680 loss: 0.036
# Epoch 690 loss: 0.035
# Epoch 690 loss: 0.035
# Epoch 690 loss: 0.035
# Epoch 690 loss: 0.035
# Epoch 690 loss: 0.035
# Epoch 700 loss: 0.034
# Epoch 700 loss: 0.034
# Epoch 700 loss: 0.034
# Epoch 700 loss: 0.034
# Epoch 700 loss: 0.034
# Epoch 710 loss: 0.033
# Epoch 710 loss: 0.033
# Epoch 710 loss: 0.033
# Epoch 710 loss: 0.033
# Epoch 710 loss: 0.033
# Epoch 720 loss: 0.032
# Epoch 720 loss: 0.032
# Epoch 720 loss: 0.032
# Epoch 720 loss: 0.032
# Epoch 720 loss: 0.032
# Epoch 730 loss: 0.031
# Epoch 730 loss: 0.031
# Epoch 730 loss: 0.031
# Epoch 730 loss: 0.031
# Epoch 730 loss: 0.031
# Epoch 740 loss: 0.030
# Epoch 740 loss: 0.030
# Epoch 740 loss: 0.030
# Epoch 740 loss: 0.030
# Epoch 740 loss: 0.030
# Epoch 750 loss: 0.029
# Epoch 750 loss: 0.029
# Epoch 750 loss: 0.029
# Epoch 750 loss: 0.029
# Epoch 750 loss: 0.029
# Epoch 760 loss: 0.029
# Epoch 760 loss: 0.029
# Epoch 760 loss: 0.029
# Epoch 760 loss: 0.029
# Epoch 760 loss: 0.029
# Epoch 770 loss: 0.028
# Epoch 770 loss: 0.028
# Epoch 770 loss: 0.028
# Epoch 770 loss: 0.028
# Epoch 770 loss: 0.028
# Epoch 780 loss: 0.027
# Epoch 780 loss: 0.027
# Epoch 780 loss: 0.027
# Epoch 780 loss: 0.027
# Epoch 780 loss: 0.027
# Epoch 790 loss: 0.026
# Epoch 790 loss: 0.026
# Epoch 790 loss: 0.026
# Epoch 790 loss: 0.026
# Epoch 790 loss: 0.026
# Epoch 800 loss: 0.026
# Epoch 800 loss: 0.026
# Epoch 800 loss: 0.026
# Epoch 800 loss: 0.026
# Epoch 800 loss: 0.026
# Epoch 810 loss: 0.025
# Epoch 810 loss: 0.025
# Epoch 810 loss: 0.025
# Epoch 810 loss: 0.025
# Epoch 810 loss: 0.025
# Epoch 820 loss: 0.025
# Epoch 820 loss: 0.024
# Epoch 820 loss: 0.024
# Epoch 820 loss: 0.024
# Epoch 820 loss: 0.024
# Epoch 830 loss: 0.024
# Epoch 830 loss: 0.024
# Epoch 830 loss: 0.024
# Epoch 830 loss: 0.024
# Epoch 830 loss: 0.024
# Epoch 840 loss: 0.023
# Epoch 840 loss: 0.023
# Epoch 840 loss: 0.023
# Epoch 840 loss: 0.023
# Epoch 840 loss: 0.023
# Epoch 850 loss: 0.023
# Epoch 850 loss: 0.023
# Epoch 850 loss: 0.023
# Epoch 850 loss: 0.023
# Epoch 850 loss: 0.023
# Epoch 860 loss: 0.022
# Epoch 860 loss: 0.022
# Epoch 860 loss: 0.022
# Epoch 860 loss: 0.022
# Epoch 860 loss: 0.022
# Epoch 870 loss: 0.022
# Epoch 870 loss: 0.022
# Epoch 870 loss: 0.022
# Epoch 870 loss: 0.022
# Epoch 870 loss: 0.022
# Epoch 880 loss: 0.021
# Epoch 880 loss: 0.021
# Epoch 880 loss: 0.021
# Epoch 880 loss: 0.021
# Epoch 880 loss: 0.021
# Epoch 890 loss: 0.021
# Epoch 890 loss: 0.021
# Epoch 890 loss: 0.021
# Epoch 890 loss: 0.021
# Epoch 890 loss: 0.021
# Epoch 900 loss: 0.020
# Epoch 900 loss: 0.020
# Epoch 900 loss: 0.020
# Epoch 900 loss: 0.020
# Epoch 900 loss: 0.020
# Epoch 910 loss: 0.020
# Epoch 910 loss: 0.020
# Epoch 910 loss: 0.020
# Epoch 910 loss: 0.020
# Epoch 910 loss: 0.020
# Epoch 920 loss: 0.019
# Epoch 920 loss: 0.019
# Epoch 920 loss: 0.019
# Epoch 920 loss: 0.019
# Epoch 920 loss: 0.019
# Epoch 930 loss: 0.019
# Epoch 930 loss: 0.019
# Epoch 930 loss: 0.019
# Epoch 930 loss: 0.019
# Epoch 930 loss: 0.019
# Epoch 940 loss: 0.019
# Epoch 940 loss: 0.019
# Epoch 940 loss: 0.019
# Epoch 940 loss: 0.019
# Epoch 940 loss: 0.019
# Epoch 950 loss: 0.018
# Epoch 950 loss: 0.018
# Epoch 950 loss: 0.018
# Epoch 950 loss: 0.018
# Epoch 950 loss: 0.018
# Epoch 960 loss: 0.018
# Epoch 960 loss: 0.018
# Epoch 960 loss: 0.018
# Epoch 960 loss: 0.018
# Epoch 960 loss: 0.018
# Epoch 970 loss: 0.017
# Epoch 970 loss: 0.017
# Epoch 970 loss: 0.017
# Epoch 970 loss: 0.017
# Epoch 970 loss: 0.017
# Epoch 980 loss: 0.017
# Epoch 980 loss: 0.017
# Epoch 980 loss: 0.017
# Epoch 980 loss: 0.017
# Epoch 980 loss: 0.017
# Epoch 990 loss: 0.017
# Epoch 990 loss: 0.017
# Epoch 990 loss: 0.017
# Epoch 990 loss: 0.017
# Epoch 990 loss: 0.017

# %%
# Create an array representing the features (height and weight) of the fifth user
name5 = np.array([0.76978417, 0.02158273])

# Feed the features of the fifth user to the trained network and print the output prediction
print("Name 5: %.3f" % network.feedforward(name5))
# Out:
# Name 5: 0.115
